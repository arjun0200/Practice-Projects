# %% [markdown]
# # Advertising Sales Channel Prediction

# %% [markdown]
# #### Problem Statement:
# Sales Channel Prediction Case Study
#
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Advertising.csv")

# %%
df.to_csv('Advertising.csv', index = False)

# %%
pd.read_csv("Advertising.csv")  #Saving dataset for future references
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/arjun0200/Datasets/main/Advertising.csv")
df.head(5)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# From above dataset we can see that Unnamed:0 column which is not a part of dataset it automatically generates due to indexing value true.
#
# Hence we need to drop it for best dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.tail(5)
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df.sample(5)
# Out:
#         TV  radio  newspaper  sales
# 34    95.7    1.4        7.4    9.5
# 151  121.0    8.4       48.7   11.6
# 161   85.7   35.8       49.3   13.3
# 71   109.8   14.3       31.7   12.4
# 108   13.1    0.4       25.6    5.3

# %%
#checking null values

df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
#checking null values visually
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### From above code we find that there is no null values present in the dataset

# %%
df.value_counts().unique()   # dataset didn't having any unique value counts all are continuos values
# Out:
# array([1], dtype=int64)

# %%
df.info()  # checking information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()   # checking quick summary of the dataset
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.describe()[1:].transpose(), annot = True, fmt = ".2f", linecolor = 'black', linewidths = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x = 'TV', y = 'sales', data = df)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %% [markdown]
# #### From above graph we can say that as the TV channels increases with sales

# %%
sns.scatterplot(x = 'radio', y = 'sales', data = df)
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %% [markdown]
# #### From above graph we can say that as the radio channels increases with sales

# %%
sns.scatterplot(x = 'newspaper', y = 'sales', data = df)
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# #### From above graph we can say that as the newspaper are scatter with sales but more lies between 0 to 60 ranges

# %% [markdown]
# ### Checking Bivariate plot

# %%
for i in range(len(df.columns)):
    for j in df.columns[i+1:]:
        sns.scatterplot(df[df.columns[i]], df[j], color = 'c')
        plt.show()

# %% [markdown]
# #### Checking distribution of data with respect to each columns dataset

# %% [markdown]
# ####

# %% [markdown]
# #### Stripplot/Swarmplot

# %%
for i in df.columns:
    plt.figure()
    sns.stripplot(x = df[i], y = df['sales'],)
    plt.show()

# %%
for i in df.columns:
    plt.figure(figsize = (5,5))
    df.groupby(i)['sales'].median().plot()
    plt.show()

# %% [markdown]
# #### From above inline graph we can say that all columns increases and sales also increase accordingly

# %% [markdown]
# ####

# %% [markdown]
# # Violin Plot

# %%
for i in df.columns:
    plt.figure()
    sns.violinplot(df[i], data = df)
    plt.show()

# %% [markdown]
# ### checking spreading density of the data`

# %% [markdown]
# ####

# %%
for i in df.columns:
    plt.figure()
    sns.histplot(x = df['sales'], y = df[i],  bins = 20)
    plt.show()

# %% [markdown]
# #### From above graph we can see that darker colors shows higher sales in ranges of the data set with respect to sales and respective columns

# %% [markdown]
# # Checking outliers

# %%
for i in df.columns:
    plt.figure(figsize = (5,5))
    sns.boxplot(df[i], orient='v', color='orange',)

# %% [markdown]
# #### From above observations we find that only newspaper having outliers

# %% [markdown]
# ####

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
for i in df.columns:
    plt.figure(figsize = (1,0.5))
    sns.displot(df[i], kind = 'kde', color = 'red')

# %% [markdown]
# #### From above graphs we conclude that radio and TV having some skewness

# %% [markdown]
# ####

# %% [markdown]
# # Checking distributions of the dataset

# %%
df.plot(kind = 'density', subplots = True, sharex = False, legend = False, figsize = (10,8), fontsize = 1)
plt.show()

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i], bins = 10)

# %% [markdown]
# TV shows more distributions towards 200 to 300 ranges
#
# Radio shows more right distributions towards 0 to 20 ranges

# %% [markdown]
# ####

# %% [markdown]
# # Pairplot to check dataset in a single glimpse

# %%
sns.pairplot(df)

# %% [markdown]
# # Checking correlation of the dataset

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), annot = True, fmt = ".2f", linecolor='black', linewidths='1', cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## From above visuallization we can find that there is no negative correlation with the dataset

# %% [markdown]
# #

# %% [markdown]
# # Removing outliers from the dataset

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))

#np.where(z>3)
# (array([ 16, 101], dtype=int64), array([2, 2], dtype=int64))

df_new = df[(z<3).all(axis = 1)]

# %%
# print(df.shape)  (200, 4)

# print(df_new.shape) (198, 4)

# %% [markdown]
# #### Percentage of dataloss

# %%
print("Percentage of data loss", ((200-198)/200)*100)
# Out:
# Percentage of data loss 1.0

# %%
for i in df.columns:
    plt.figure()
    sns.boxplot(df[i])

# %% [markdown]
# #### Checking visually outliers after using zscore method to remove outliers

# %% [markdown]
# #### We observe that Newspaper having some values which show high in numbers

# %% [markdown]
# ### Zscore gives us low data loss hence we are considering it for feature selection

# %% [markdown]
# # Dividing Dataset for Feature Selection

# %%
x = df_new.iloc[:,:-1]
y = df_new.iloc[:,-1]

# %%
print(x.shape)
print(y.shape)
# Out:
# (198, 3)
# (198,)

# %% [markdown]
# # Removing Skewness

# %%
from sklearn.preprocessing import power_transform

x_skew = power_transform(x)

# %%
x = pd.DataFrame(x_skew, columns = x.columns)

# %%
x.skew()
# Out:
# TV          -0.320682
# radio       -0.236668
# newspaper   -0.101288
# dtype: float64

# %% [markdown]
# #### From observations we find that skewness show negativity in all values hence we need to remove it

# %%
x = 1-x

# %%
x.skew()  # now new x will be in positive format
# Out:
# TV           0.320682
# radio        0.236668
# newspaper    0.101288
# dtype: float64

# %%
for i in x.columns:
    plt.figure()
    sns.displot(x[i], kind = 'kde', color = 'red')

# %% [markdown]
# #### Shape has been changed from previous skewness

# %% [markdown]
# # We are not checking VIF due to less number of dataset columns present in the dataset

# %% [markdown]
# ###

# %% [markdown]
# # Scaling Dataset

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaler = sc.fit_transform(x)

# %%
x = x_scaler

# %% [markdown]
# # Feature Selection

# %% [markdown]
# #### Since output variables having continuos variables hence we use regression model`

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression, SGDRegressor, Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
class best_model:
    def best_fit(x, y, model):
        random_state_values = []
        for i in range(0,200):
            x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = i, test_size = 0.30)
            model.fit(x_train, y_train)
            pred_train = model.predict(x_train)
            pred_test = model.predict(x_test)

            if round(r2_score(y_train, pred_train)*100,1) == round(r2_score(y_test, pred_test)*100,1):
                print("At random_state:-", i)
                print("Training r2_score is:-", r2_score(pred_train, y_train)*100)
                print("Testing r2_score is:-", r2_score(pred_test, y_test)*100)
                print("\n")
                random_state_values.append(i)
        print("Best fit random_state_values", random_state_values)
    
    
    def final_model(x, y, model, i):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = i)
        model.fit(x_train, y_train)
        pred_train = model.predict(x_train)
        pred_test = model.predict(x_test)
        print("At random state", i , "model giving best accuracy score","\n")
        Train_accuracy = r2_score(pred_train, y_train)
        Test_accuracy = r2_score(pred_test, y_test)
        print('Training accuracy:- ', Train_accuracy*100)
        print('Testing accuracy:- ', Test_accuracy*100)
        print("\n")
        print('--------------------------------------')
        print('Mean squared error:- ', mean_squared_error(pred_test, y_test) )
        print('Mean absolute error:- ', mean_absolute_error(pred_test, y_test) )
        print('Root Mean squared error:-',np.sqrt(mean_squared_error(pred_test, y_test)))
        
        
    def cross_val_score(model, x, y):
        for value in range(2,8):
            cv = cross_val_score(model, x, y, cv = value).mean()
            print('cross_val_score', cv*100,'at cv =', value, "\n")

# %% [markdown]
# ## Model 1 Linear Regression

# %%
model = LinearRegression()
best_model.best_fit(x, y, model)
# Out:
# At random_state:- 122
# Training r2_score is:- 89.46220856025074
# Testing r2_score is:- 89.41002009005162
#
#
# At random_state:- 131
# Training r2_score is:- 89.15690107593804
# Testing r2_score is:- 87.22909127303828
#
#
# Best fit random_state_values [122, 131]

# %%
best_model.final_model(x, y, model, 151)   # at random state 151 model shows best accuracy
# Out:
# At random state 151 model giving best accuracy score
#
# Training accuracy:-  88.54568000988674
# Testing accuracy:-  91.19458526558452
#
#
# --------------------------------------
# Mean squared error:-  2.18470895047584
# Mean absolute error:-  1.1498746151972177
# Root Mean squared error:- 1.4780760976606853

# %%
best_model.cross_val_score(model, x, y)
# Out:
# cross_val_score 90.17064197605747 at cv = 2
#
# cross_val_score 89.73645562112826 at cv = 3
#
# cross_val_score 89.86654359289577 at cv = 4
#
# cross_val_score 89.5827096855507 at cv = 5
#
# cross_val_score 89.87009469201537 at cv = 6
#
# cross_val_score 89.4944294999198 at cv = 7

# %% [markdown]
# ## Model 2 Random Forest Regressor

# %%
model = RandomForestRegressor()
best_model.best_fit(x, y, model)
# Out:
# Best fit random_state_values []

# %% [markdown]
# #### From above model we find that there is no random state which fit training and testing accuracy simultaneously

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
# using hyper parameter tuning for decision tree regressor to find out best criterion

model = SVR()
param = {'kernel': ['linear', 'rbf', 'poly']}

gd = GridSearchCV(model, param_grid=param)
gd.fit(x, y)
gd.best_params_


# {'kernel': 'rbf'}
# Out:
# {'kernel': 'rbf'}

# %% [markdown]
# ## Model 3 Support Vector Regressor

# %%
model = SVR(kernel = 'rbf')

best_model.best_fit(x, y, model)
# Out:
# At random_state:- 74
# Training r2_score is:- 82.3571378916368
# Testing r2_score is:- 80.61425721581423
#
#
# At random_state:- 105
# Training r2_score is:- 88.70258268629921
# Testing r2_score is:- 89.481621581078
#
#
# At random_state:- 179
# Training r2_score is:- 88.23479865848604
# Testing r2_score is:- 88.309844081665
#
#
# Best fit random_state_values [74, 105, 179]

# %%
best_model.final_model(x, y, model, 179) # model gives best accuracy at random state 179
# Out:
# At random state 179 model giving best accuracy score
#
# Training accuracy:-  88.23479865848604
# Testing accuracy:-  88.309844081665
#
#
# --------------------------------------
# Mean squared error:-  1.5874852530465189
# Mean absolute error:-  0.7241938039452758
# Root Mean squared error:- 1.2599544646718464

# %%
best_model.cross_val_score(model, x, y)
# Out:
# cross_val_score 86.6028444179995 at cv = 2
#
# cross_val_score 89.95351608744402 at cv = 3
#
# cross_val_score 91.35257569293861 at cv = 4
#
# cross_val_score 92.02978192122427 at cv = 5
#
# cross_val_score 92.11852040016363 at cv = 6
#
# cross_val_score 92.14852078488843 at cv = 7

# %% [markdown]
# ####

# %% [markdown]
# ## Model 4 SGD Regressor  for minimum cost function

# %%
model = SGDRegressor(learning_rate='optimal',alpha = 0.01)

best_model.best_fit(x, y, model)
# Out:
# At random_state:- 51
# Training r2_score is:- 86.88338357204705
# Testing r2_score is:- 87.30729978330143
#
#
# At random_state:- 64
# Training r2_score is:- 88.44019191003909
# Testing r2_score is:- 89.57665612913866
#
#
# At random_state:- 188
# Training r2_score is:- 88.31512709392459
# Testing r2_score is:- 87.28097406682377
#
#
# Best fit random_state_values [51, 64, 188]

# %%
best_model.final_model(x, y, model, 134)   # at random state 134 model shows best accuracy
# Out:
# At random state 134 model giving best accuracy score
#
# Training accuracy:-  88.09398531727868
# Testing accuracy:-  85.02039494890766
#
#
# --------------------------------------
# Mean squared error:-  3.3232690027014424
# Mean absolute error:-  1.3524238295219169
# Root Mean squared error:- 1.8229835442760975

# %%
best_model.cross_val_score(model, x, y)
# Out:
# cross_val_score 89.69384021315621 at cv = 2
#
# cross_val_score 89.19911894368852 at cv = 3
#
# cross_val_score 89.81764041326679 at cv = 4
#
# cross_val_score 89.26383733982897 at cv = 5
#
# cross_val_score 89.39586015889844 at cv = 6
#
# cross_val_score 89.43839839134881 at cv = 7

# %% [markdown]
# ## Model 5 Decision Tree Regressor

# %%
model = DecisionTreeRegressor()

best_model.best_fit(x, y, model)
# Out:
# Best fit random_state_values []

# %% [markdown]
# #### From above model we find that there is no random state which fit training and testing accuracy simultaneously

# %% [markdown]
# ## Model 6 Random Forest Regressor

# %%
model = RandomForestRegressor()
best_model.best_fit(x, y, model)
# Out:
# Best fit random_state_values []

# %% [markdown]
# ## Regularization Method to making low coef. values

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
model = Lasso()
param = {'alpha': [0.1,0.01,0.001]}

gd = GridSearchCV(model, param_grid=param)
gd.fit(x, y)
gd.best_params_
# Out:
# {'alpha': 0.01}

# %% [markdown]
# ## Model 7 Lasso Regression

# %%
model = Lasso(alpha=0.01)
best_model.best_fit(x, y, model)
# Out:
# At random_state:- 16
# Training r2_score is:- 89.34806739108218
# Testing r2_score is:- 88.26030302601596
#
#
# At random_state:- 122
# Training r2_score is:- 89.40295556549276
# Testing r2_score is:- 89.37126499490613
#
#
# Best fit random_state_values [16, 122]

# %%
best_model.final_model(x, y, model, 137)   # at random state 137 model shows best accuracy
# Out:
# At random state 137 model giving best accuracy score
#
# Training accuracy:-  89.65329331188612
# Testing accuracy:-  89.35489255882429
#
#
# --------------------------------------
# Mean squared error:-  2.3981618512922984
# Mean absolute error:-  1.276861168563532
# Root Mean squared error:- 1.5485999649012971

# %%
best_model.cross_val_score(model, x, y)
# Out:
# cross_val_score 90.18709812664905 at cv = 2
#
# cross_val_score 89.74401694716117 at cv = 3
#
# cross_val_score 89.86597444889955 at cv = 4
#
# cross_val_score 89.59751846282693 at cv = 5
#
# cross_val_score 89.87081812723883 at cv = 6
#
# cross_val_score 89.49476564509656 at cv = 7

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
model = Ridge()
param = {'alpha': [0.1,0.01,0.001]}

gd = GridSearchCV(model, param_grid=param)
gd.fit(x, y)
gd.best_params_
# Out:
# {'alpha': 0.1}

# %% [markdown]
# ## Model 7 Ridge Regression

# %%
model = Ridge(alpha=0.1)
best_model.best_fit(x, y, model)
# Out:
# At random_state:- 122
# Training r2_score is:- 89.44801967790012
# Testing r2_score is:- 89.3927882131528
#
#
# Best fit random_state_values [122]

# %%
best_model.final_model(x, y, model, 151)  # at random state 137 model shows best accuracy
# Out:
# At random state 151 model giving best accuracy score
#
# Training accuracy:-  88.52957944537587
# Testing accuracy:-  91.18082940627673
#
#
# --------------------------------------
# Mean squared error:-  2.185052771227903
# Mean absolute error:-  1.1497660284125442
# Root Mean squared error:- 1.4781923999357807

# %%
best_model.cross_val_score(model, x, y)
# Out:
# cross_val_score 90.17042410259775 at cv = 2
#
# cross_val_score 89.737450003991 at cv = 3
#
# cross_val_score 89.86650111400718 at cv = 4
#
# cross_val_score 89.58395405521023 at cv = 5
#
# cross_val_score 89.8699714400549 at cv = 6
#
# cross_val_score 89.49502712353346 at cv = 7

# %% [markdown]
# ## From above models we are selection Support Vector Regressor which gives almost 90 percent accuracy with less error ratio with other model and not overfitted model
#
# Mean squared error:-  1.5874852530465189
#
# Mean absolute error:-  0.7241938039452758
#
# Root Mean squared error:- 1.2599544646718464

# %%
model = SVR(kernel = 'rbf')
best_model.best_fit(x, y, model)
# Out:
# At random_state:- 74
# Training r2_score is:- 82.3571378916368
# Testing r2_score is:- 80.61425721581423
#
#
# At random_state:- 105
# Training r2_score is:- 88.70258268629921
# Testing r2_score is:- 89.481621581078
#
#
# At random_state:- 179
# Training r2_score is:- 88.23479865848604
# Testing r2_score is:- 88.309844081665
#
#
# Best fit random_state_values [74, 105, 179]

# %%
best_model.final_model(x, y, model, 179)
# Out:
# At random state 179 model giving best accuracy score
#
# Training accuracy:-  88.23479865848604
# Testing accuracy:-  88.309844081665
#
#
# --------------------------------------
# Mean squared error:-  1.5874852530465189
# Mean absolute error:-  0.7241938039452758
# Root Mean squared error:- 1.2599544646718464

# %%
best_model.cross_val_score(model, x, y)  # model didn't show overfitting because cross val score lies with in the range of +/-3 with model accuracy
# Out:
# cross_val_score 86.6028444179995 at cv = 2
#
# cross_val_score 89.95351608744402 at cv = 3
#
# cross_val_score 91.35257569293861 at cv = 4
#
# cross_val_score 92.02978192122427 at cv = 5
#
# cross_val_score 92.11852040016363 at cv = 6
#
# cross_val_score 92.14852078488843 at cv = 7

# %% [markdown]
# # Checking with Graph

# %%
final_model = SVR()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 50)
final_model.fit(x_train, y_train)
final_pred = final_model.predict(x_test)
Test_accuracy = r2_score(pred_test, y_test)
plt.figure(figsize = (12, 8))
plt.scatter(x = y_test, y = final_pred, color = 'c')
plt.plot(y_test, y_test, color = 'r')
plt.xlabel('Actual Sales', fontsize = 12)
plt.ylabel('Predicted Sales', fontsize = 12)
plt.title('Support Vector Regressor')
plt.show()

# %% [markdown]
# ## Deploy Model

# %%
import pickle

filename = 'Advertising_sales.pkl'
pickle.dump(final_model, open(filename, 'wb'))

# %% [markdown]
# ## Load Model

# %%
load = pickle.load(open('Advertising_sales.pkl', 'rb'))
results = load.score(x_test,y_test)
results
# Out:
# 0.9328984786458284

# %% [markdown]
# ####

# %% [markdown]
# ## Conclusion

# %%
conclusion = pd.DataFrame()
conclusion['Predicted Sales'] = np.array(load.predict(x_test))
conclusion['Actual Sales'] = np.array(y_test)

# %%
pd.set_option("display.max_rows", None)

# %%
conclusion
# Out:
#     Predicted Sales  Actual Sales
# 0          8.154122           7.6
# 1         12.446955          12.0
# 2         19.660190          19.0
# 3         12.468178          12.5
# 4         21.344650          23.7
# 5         13.096002          13.4
# 6         19.784670          20.2
# 7         10.221518           4.8
# 8         10.638960          11.2
# 9         16.545259          16.6
# 10         9.815707           9.2
# 11         9.288911           8.8
# 12        14.828424          15.0
# 13         9.340492           9.7
# 14        22.246095          25.4
# 15        16.085092          15.0
# 16        12.379307          12.3
# 17        12.295395          11.7
# 18        11.897146          11.5
# 19         9.734329           9.6
# 20        18.198883          18.0
# 21        15.322755          15.7
# 22        17.627822          18.0
# 23        10.908398          11.3
# 24        17.230393          17.1
# 25        19.656633          20.8
# ...
